# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
#open the image
img=cv2.imread('billi.png')
plt.imshow(img)
plt.show()
#load the image
mask=cv2.imread('im1.png',0)
plt.imshow(mask)
plt.show()
#inpaint
dst=cv2.inpaint(img,mask,3,cv2.INPAINT_NS)
#write the output
cv2.imwrite('dimage_inpainted.png',dst)
plt.imshow(dst)
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt


from skimage.util import random_noise
fruit_image=plt.imread('fruitts.jpeg')

#Add noise to the image
noisy_image=random_noise(fruit_image)

#show th original and resulting image
plot_comparison(fruit_image,noisy_image,'Noisy.jpg')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10480/1813683387.py in <module>
#       4
#       5 from skimage.util import random_noise
# ----> 6 fruit_image=plt.imread('fruitts.jpeg')
#       7
#       8 #Add noise to the image
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in imread(fname, format)
#    2405 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2406 def imread(fname, format=None):
# -> 2407     return matplotlib.image.imread(fname, format)
#    2408
#    2409
#
# ~\Anaconda3\lib\site-packages\matplotlib\image.py in imread(fname, format)
#    1499                     response = io.BytesIO(response.read())
#    1500                 return imread(response, format=ext)
# -> 1501     with img_open(fname) as image:
#    1502         return (_pil_png_to_float_array(image)
#    1503                 if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#
# ~\Anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    2973
#    2974     if filename:
# -> 2975         fp = builtins.open(filename, "rb")
#    2976         exclusive_fp = True
#    2977
#
# FileNotFoundError: [Errno 2] No such file or directory: 'fruitts.jpeg'

# %%
from skimage.restoration import denoise_tv_chambolle

noisy_image=plt.imread('noisy.jpg')

#Apply total variation filtern denoising
denoised_image=denoise_tv_chambolle(noisy_image,multichannel=True)

#show the noisy and denoised image
plot_comparison(noisy_image,denoised_image,'Denoised Image')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10480/2419231912.py in <module>
#       1 from skimage.restoration import denoise_tv_chambolle
#       2
# ----> 3 noisy_image=plt.imread('noisy.jpg')
#       4
#       5 #Apply total variation filtern denoising
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in imread(fname, format)
#    2405 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2406 def imread(fname, format=None):
# -> 2407     return matplotlib.image.imread(fname, format)
#    2408
#    2409
#
# ~\Anaconda3\lib\site-packages\matplotlib\image.py in imread(fname, format)
#    1499                     response = io.BytesIO(response.read())
#    1500                 return imread(response, format=ext)
# -> 1501     with img_open(fname) as image:
#    1502         return (_pil_png_to_float_array(image)
#    1503                 if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#
# ~\Anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    2973
#    2974     if filename:
# -> 2975         fp = builtins.open(filename, "rb")
#    2976         exclusive_fp = True
#    2977
#
# FileNotFoundError: [Errno 2] No such file or directory: 'noisy.jpg'

# %%
from skimage.restoration import denoise_bilateral

landscape_image= plt.imread('noisy.jpg')

#Apply bilateral filletr denoising
denoised_image=denoise_bilateral(landscape_image,multichannel=True)

#show original and resulting images
plot_comparison(landscape_image,denoised_image,'Denoised Image')
# Out:
#   File "C:\Users\user\AppData\Local\Temp/ipykernel_10480/1662247771.py", line 1
#     irom skimage.restoration import denoise_bilateral
#          ^
# SyntaxError: invalid syntax

# %%
#Segmentation:

from skimage.segmentation import slic
from skimage.color import label2rgb

face_image=plt.imread('face.jpg')

#obtain the segmentation with 400 regions
segments=slic(face_image,n_segments=400)

#put segments on top of original image to compare
segmented_image= label2rgb(segments,face_image,kind='avg')

#show the segmented image
plot_comparison(face_image,segmented_image,'segmented image,400 superpixels')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10480/2284641424.py in <module>
#       4 from skimage.color import label2rgb
#       5
# ----> 6 face_image=plt.imread('face.jpg')
#       7
#       8 #obtain the segmentation with 400 regions
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in imread(fname, format)
#    2405 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2406 def imread(fname, format=None):
# -> 2407     return matplotlib.image.imread(fname, format)
#    2408
#    2409
#
# ~\Anaconda3\lib\site-packages\matplotlib\image.py in imread(fname, format)
#    1499                     response = io.BytesIO(response.read())
#    1500                 return imread(response, format=ext)
# -> 1501     with img_open(fname) as image:
#    1502         return (_pil_png_to_float_array(image)
#    1503                 if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#
# ~\Anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    2973
#    2974     if filename:
# -> 2975         fp = builtins.open(filename, "rb")
#    2976         exclusive_fp = True
#    2977
#
# FileNotFoundError: [Errno 2] No such file or directory: 'face.jpg'
